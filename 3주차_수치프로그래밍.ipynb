# %% [markdown]
# <a href="https://colab.research.google.com/github/linearAlgebra2024/linearAlgebra/blob/feat-minje/3%EC%A3%BC%EC%B0%A8_%EC%88%98%EC%B9%98%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.array([4,3])

fig=plt.figure()

ax = fig.add_subplot(1,1,1)

ax.scatter(a[0],a[1], s=30)

ax.text(a[0]+0.2, a[1]+0.2, 'a', size=15)

ax.set_xticks(range(-5,6))
ax.set_yticks(range(-5,6))

ax.grid()
ax.set_axisbelow(True)

ax.set_aspect('equal', adjustable='box')

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.array([4,3])

fig=plt.figure()

ax = fig.add_subplot(1,1,1)

ax.quiver(0,0,a[0], a[1],angles='xy', scale_units='xy', scale=1)
ax.text(a[0], a[1], 'a', size=15)

ax.set_xticks(range(0,7))
ax.set_yticks(range(0,7))

ax.grid()
ax.set_axisbelow(True)

ax.set_aspect('equal', adjustable='box')

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

A=np.array([1,-2])
B=np.array([4,3])

f,ax=plt.subplots(1,2)
ax[0].title.set_text('A')
ax[1].title.set_text('B')

ax[0].quiver(0,0,A[0],A[1],angles='xy',scale_units ='xy', scale=1)
ax[1].quiver(0,0,B[0],B[1],angles='xy',scale_units ='xy', scale=1)

start_x=-1
end_x=5
start_y=-3
end_y=4

for i in range(2):
  ax[i].axis([start_x,end_x,start_y,end_y])
  ax[i].set_xticks(range(start_x,end_x))
  ax[i].set_yticks(range(start_y,end_y))
  ax[i].grid(True)
  ax[i].set_aspect('equal', adjustable='box')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

A=np.array([4,5,6])
fig=plt.figure()

ax=fig.add_subplot(1,1,1,projection='3d')

ax.quiver(0,0,0,A[0],A[1],A[2], color='black', arrow_length_ratio=0.1)
ax.text(A[0],A[1],A[2], 'a',size=15)

ax.set_xlim(0,8)
ax.set_ylim(0,8)
ax.set_zlim(0,8)
ax.set_xlabel('X')
ax.set_xlabel('Y')
ax.set_xlabel('z')
ax.view_init(elev=20.,azim=5)
ax.grid()
ax.set_axisbelow(True)
ax.set_aspect('auto', adjustable='box')
plt.show()

# %% [markdown]
# 벡터의 정의

# %%
import numpy as np
a= np.array([4,3])
print(a.shape)
print(a.T.shape)
# Out:
# (2,)
# (2,)

# %% [markdown]
# 벡터의 성분

# %%
import numpy as np
a=np.array([4,3])

print(a.shape)

a.shape=(2,1)
print(a)

a.shape=(1,2)
print(a)
# Out:
# (2,)
# [[4]
#  [3]]
# [[4 3]]

# %%
import numpy as np
import matplotlib.pyplot as plt

i=np.array([1,0])
j=np.array([0,1])

a=4*i+3*j

fig=plt.figure()
ax=fig.add_subplot(1,1,1)

ax.quiver(0,0,a[0],a[1],angles='xy', scale_units='xy',scale=1)
ax.text(a[0],a[1],'4i+3j', size=15)

ax.set_xticks(range(0,7))
ax.set_yticks(range(0,7))
ax.grid()
ax.set_axisbelow(True)
ax.set_aspect('equal', adjustable='box')

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.show()

# %% [markdown]
# 벡터의 기본 연산(덧셈)

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.array([4,1])
b=np.array([-2,3])
sum=a+b

fig=plt.figure()
ax=fig.add_subplot(1,1,1)

plt.quiver(0,0,a[0],a[1],angles='xy', scale_units='xy', scale=1, color='blue')
ax.text(a[0], a[1], 'a', size=15)

ax.quiver(a[0], a[1], b[0], b[1], angles='xy', scale_units='xy', scale=1, color='green')
ax.text(a[0]+b[0],a[1]+b[1],'b',size=15)

ax.quiver(0,0,sum[0],sum[1],angles='xy', scale_units='xy', scale=1, color="red")
ax.text(sum[0]*0.5+0.3, b[1], 'a+b', size=15, color='blue')

ax.set_xticks(range(0,7))
ax.set_yticks(range(0,7))
ax.grid()
ax.set_axisbelow(True)
ax.set_aspect('equal', adjustable='box')

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.show()

# %% [markdown]
# 벡터의 기본 연산 (뺄셈)

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.array([4,1])
b=np.array([-2,3])
sum=a-b

fig=plt.figure()
ax=fig.add_subplot(1,1,1)

ax.quiver(0,0,a[0],a[1],angles='xy',scale_units='xy',scale=1,color='blue')
ax.text(a[0],a[1],'a',size=15)

ax.quiver(a[0],a[1],-b[0],-b[1],angles='xy',scale_units='xy',scale=1,color='green')
ax.text(a[0]-b[1],a[1]-b[1],'b',size=15)

ax.quiver(0,0,sum[0],sum[1],angles='xy',scale_units='xy',scale=1,color='red')
ax.text(sum[0]*0.5+0.3, b[1],'a-b',size=15,color='blue')

ax.set_xticks(range(-2,8))
ax.set_yticks(range(-4,5))
ax.grid()
ax.set_axisbelow(True)
ax.set_aspect('equal',adjustable='box')

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.show()

# %% [markdown]
# 벡터의 기본연산 (스칼라곱)

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.array([4,1])
c=3
ca=np.multiply(c,a)

fig=plt.figure()
ax=fig.add_subplot(1,1,1)

plt.quiver(0,0,a[0],a[1],angles='xy',scale_units='xy',scale=1,color='blue')
ax.text(a[0],a[1],'a',size=15)

ax.quiver(0,1,ca[0],ca[1],angles='xy', scale_units='xy', scale=1,color='green')
ax.text(ca[0], ca[1]+1,'3a', size=15, color='blue')

ax.set_xticks(range(-2,15))
ax.set_yticks(range(-3,9))
ax.grid()
ax.set_axisbelow(True)
ax.set_aspect('equal', adjustable='box')

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.show()

# %% [markdown]
# 내적(dot product)

# %%
import numpy as np
a=np.array([1,2])
b=np.array([2,3])
print(np.dot(a,b))
# Out:
# 8

# %%
import numpy as np
a=np.array([1,2])
print(np.linalg.norm(a))
print(np.sqrt(5))
# Out:
# 2.23606797749979
# 2.23606797749979

# %% [markdown]
# 내적(dot product)(2)

# %%
import numpy as np
a=np.array([1,2])

print(np.sqrt(np.dot(a,a)))
print(np.linalg.norm(a))
# Out:
# 2.23606797749979
# 2.23606797749979

# %%
import numpy as np
a=np.array([3,3])
b=np.array([3,0])

print(np.dot(a,b))

norm_a=np.linalg.norm(a)
norm_b=np.linalg.norm(b)
print(norm_a*norm_b*np.cos(45*np.pi/180))
# Out:
# 9
# 9.0

# %%
import numpy as np
a=np.array([3,0])
b=np.array([0,3])

print(np.dot(a,b))
# Out:
# 0

# %% [markdown]
# 외적(cross product)

# %%
import numpy as np

v=np.array([5,3,0])
w=np.array([1,2,0])

print(np.cross(v,w))
# Out:
# [0 0 7]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

a=np.array([5,3,0])
b=np.array([1,2,0])

c=np.cross(a,b)
fig=plt.figure()
ax=fig.add_subplot(1,1,1,projection='3d')

ax.quiver(0,0,0,a[0],a[1],a[2],color='black', arrow_length_ratio=0.1)
ax.text(a[0], a[1], a[2], 'a', size=15)

ax.quiver(0,0,0,b[0], b[1], b[2], color='red', arrow_length_ratio=0.1)
ax.text(b[0],b[1],b[2],'b', size=15)

ax.quiver(0,0,0,c[0],c[1],c[2],color='blue', arrow_length_ratio=0.1)
ax.text(c[0],c[1],c[2],'c',size=15)
ax.set_xlim(0,7)
ax.set_ylim(0,7)
ax.set_zlim(0,7)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('z')
ax.view_init(elev=20,azim=5)
ax.grid()
ax.set_axisbelow(True)
ax.set_aspect('auto', adjustable='box')
plt.show()

# %% [markdown]
# 외적(Cross product)(2)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

a=np.array([3,3,0])
b=np.array([6,6,0])

c=np.cross(a,b)
fig=plt.figure()
ax=fig.add_subplot(1,1,1,projection='3d')

ax.quiver(0,0,0,a[0],a[1],a[2],color='black',arrow_length_ratio=0.1)
ax.text(a[0],a[1], a[2],'a', size=15)

ax.quiver(0,0,0,b[0],b[1],b[2],color='red',arrow_length_ratio=0.1)
ax.text(b[0],b[1], b[2],'b', size=15)

ax.quiver(0,0,0,c[0],c[1],c[2],color='blue', arrow_length_ratio=0.1)
ax.text(c[0], c[1], c[2], 'c', size=15)
ax.set_xlim(0,7)
ax.set_ylim(0,7)
ax.set_zlim(0,7)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.view_init(elev=20,azim=5)
ax.grid()
ax.set_axisbelow(True)
ax.set_aspect('auto', adjustable='box')
plt.show()

# %% [markdown]
# 행렬의 정의

# %%
import numpy as np
A=np.array([[1,2,3,4], [5,6,7,8]])

print(A[0])
print(A[0,:])
print(A[1])
print(A[1,:])

print(A[:,0])
print(A[:,1])
print(A[:,2])
print(A[:,3])
# Out:
# [1 2 3 4]
# [1 2 3 4]
# [5 6 7 8]
# [5 6 7 8]
# [1 5]
# [2 6]
# [3 7]
# [4 8]

# %%
import numpy as np
A=np.array([[1,2],[3,4]])
B=np.array([[4,1],[5,2]])

print(A+B)
print(np.add(A,B))
print(A-B)
print(np.subtract(A,B))
# Out:
# [[5 3]
#  [8 6]]
# [[5 3]
#  [8 6]]
# [[-3  1]
#  [-2  2]]
# [[-3  1]
#  [-2  2]]

# %%
import numpy as np

A=np.arange(9).reshape(3,3)
print(A)
c=10
print(np.multiply(c,A))
print(c*A)
# Out:
# [[0 1 2]
#  [3 4 5]
#  [6 7 8]]
# [[ 0 10 20]
#  [30 40 50]
#  [60 70 80]]
# [[ 0 10 20]
#  [30 40 50]
#  [60 70 80]]

# %% [markdown]
# 행렬의 곱셈

# %%
import numpy as np
A=np.array([[1,2,3],[4,5,6]])
B=np.array([[4,1],[5,2],[1,2]])

print(A)
print(B)
print(A.dot(B))
print(np.dot(A,B))
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[4 1]
#  [5 2]
#  [1 2]]
# [[17 11]
#  [47 26]]
# [[17 11]
#  [47 26]]

# %%
import numpy as np
A=np.array([[1,2],[3,4]])
B=np.array([[4,1],[5,2]])

print(A*B)
print(np.multiply(A,B))
# Out:
# [[ 4  2]
#  [15  8]]
# [[ 4  2]
#  [15  8]]

# %% [markdown]
# 벡터의 전치

# %%
import numpy as np
X=np.array([[1,2],[3,4],[5,6]])
print(X)
print(X.T)
print(np.transpose(X))
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# [[1 3 5]
#  [2 4 6]]
# [[1 3 5]
#  [2 4 6]]

# %% [markdown]
# 항등행렬

# %%
import numpy as np
I=np.eye(3)
A=np.arange(9).reshape(3,3)
print(A)

print((np.dot(A,I)==A).all())
print((np.dot(I,A)==A).all())
# Out:
# [[0 1 2]
#  [3 4 5]
#  [6 7 8]]
# True
# True

# %% [markdown]
# 역행령

# %%
import numpy as np
A=np.array([[1,2],[3,4]])
invA=np.linalg.inv(A)
print(invA)

print(np.dot(A,invA))
print(np.round(np.dot(A,invA)))
print(np.round(np.dot(invA,A)))
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]
# [[1.0000000e+00 0.0000000e+00]
#  [8.8817842e-16 1.0000000e+00]]
# [[1. 0.]
#  [0. 1.]]
# [[1. 0.]
#  [0. 1.]]
